# %% [markdown]
# # Monte Carlo Result Display
# <p>The code below provide different plots and maps to visualise the performance of N-periodic ka-SPGR, the variation of T2* measurement, the bias of the T2* measurement, also the estimated efficiency for T2* measurement.<p\>

# %%
import numpy as np
import math
import random
import matplotlib.pyplot as plt
from math import log10, floor

# %% [markdown]
# ### visualise performance of a specific periodic ka-SPGR
# ### select Period want to look at

# %%
Period = 7
#Load Data
TR_n = 20
T2 = 44e-3
#T2* range 13 ms to 53 ms
T2s_min = 13
T2s_max = 53
T2p = np.asarray([], dtype = float)

for i in range (T2s_min, T2s_max):
    T2p = np.append(T2p, 1/((1000/i)-1/T2))
TR = np.asarray([], dtype = float)
TR_min = 2e-3
TR_max = 10e-3
TR_increment = (TR_max-TR_min)/TR_n
for i in range (0, TR_n):
    TR = np.append(TR, TR_min+TR_increment*i)
    
T2Star_GT = np.asarray([], dtype = float)
for T2_inhom in T2p:
        #Store Ground truth T2*------------------------------------
        T2Star_GT = np.append(T2Star_GT, 1/((1/T2)+(1/T2_inhom)))

#20TRs Monte Carlo Results        
ErrorMeanfigdata = np.load("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/"+str(Period)+"PeriodData_0.05Noise_ErrorMean.npy")
Errorstdfigdata = np.load("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/"+str(Period)+"PeriodData_0.05Noise_Errorstd.npy")
Biasfigdata = np.load("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/"+str(Period)+"PeriodData_0.05Noise_Bias.npy")
Meanfigdata = np.load("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/"+str(Period)+"PeriodData_0.05Noise_Mean.npy")

# %% [markdown]
# ## Measured T2* vs Ground truth T2* plot display

# %%
#Plot to see T2* accuracy at different TRs
from IPython.display import clear_output

for i in range(0,20):
    fig, ax = plt.subplots(figsize = (8,8))
    ax.errorbar(T2Star_GT*1e3,Meanfigdata[i,:]*1e3,fmt='o', yerr=Errorstdfigdata[i,:]*1e3,capsize=4)
    ax.set_xlabel("T2* Ground Truth (ms)")
    ax.set_ylabel("T2* Measured (ms)")
    ax.set_title("T2* Measured vs GT for "+str(Period)+" Period (TR = "+str(round(TR[i]*1e3, 3-int(floor(log10(abs(TR[i]*1e3))))-1))+" ms)")
    x1 = np.array([-20,60])
    y1 = np.array([-20,60])
    ax.plot(x1,y1,c = '#4CAF50')
    ax.set_xlim(10, 60)
    ax.set_ylim(10, 60)
    ax.grid()
    plt.show()
    clear_output(wait=True)
    #fig.savefig("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/T2StarAccuracy_"+str(Period)+"_Period_TR_"+str(round(TR[i]*1e3, 3-int(floor(log10(abs(TR[i]*1e3))))-1))+"_ms.jpg")
plt.show()

# %% [markdown]
# ## T2* percentage bias display

# %%
#Plot to see T2* accuracy at different TRs
from IPython.display import clear_output

for i in range(0,20):
    fig, ax = plt.subplots(figsize = (10,10))   
    ax.errorbar(T2Star_GT*1e3,(Meanfigdata[i,:]-T2Star_GT)/T2Star_GT*100,fmt='o', yerr=Errorstdfigdata[i,:]/Meanfigdata[i,:]*100,capsize=4)
    ax.set_xlabel("T2* Ground Truth (ms)",fontsize = 15)
    ax.set_ylabel("T2* percentage bias (%)", fontsize = 15)
    #ax.set_title("T2* Measured percentage bias for "+str(Period)+" Period (TR = "+str(round(TR[i]*1e3, 3-int(floor(log10(abs(TR[i]*1e3))))-1))+" ms)")
    ax.axhline(0, color='green', linestyle='--', alpha = 0.5)
    ax.axhline(-5, color='red', linestyle='--', alpha =0.5)
    ax.axhline(5, color='red', linestyle='--', alpha = 0.5)
    ax.set_xlim(10, 55)
    ax.set_ylim(-10, 10)

    plt.show()
    clear_output(wait=True)
    fig.savefig("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/T2StarPercentageBias_"+str(Period)+"_Period_TR_"+str(round(TR[i]*1e3, 3-int(floor(log10(abs(TR[i]*1e3))))-1))+"_ms.jpg")
plt.show()

# %% [markdown]
# ## Mean T2* Error Map

# %%
errormeancb = np.asarray([],dtype = float)
for i in range(-5,125):
    errormeancb = np.append(errormeancb, 0.04*i)
errormap, mapax = plt.subplots(figsize = (15,5))

contourImage = mapax.contourf(T2Star_GT*1e3,TR*1e3,ErrorMeanfigdata*1e3,errormeancb)
c_map_m = errormap.colorbar(contourImage, ax=mapax)
c_map_m.set_label("ms")

mapax.set_xlabel("T2 Star value (ms)")
mapax.set_ylabel("TR value (ms)")
mapax.set_title(str(Period)+" Period error mean map")
#plt.savefig("./SimulationResults/FinalPlots/"+str(Period)+"Period_TR_T2StarMeanErrorMap.jpg")
# Out:
# Text(0.5, 1.0, '6 Period error mean map')

# %% [markdown]
# ## Standard Deviation Map

# %%
errorstdcb = np.asarray([],dtype = float)
for i in range(0,150):
    errorstdcb = np.append(errorstdcb, 0.1*i)
errorstdmap, std_mapax = plt.subplots(figsize = (15,5))

contourImage = std_mapax.contourf(T2Star_GT*1e3,TR*1e3,Errorstdfigdata*1e3,errorstdcb)
c_bar_sd = errorstdmap.colorbar(contourImage, ax=std_mapax)
c_bar_sd.set_label("ms")

std_mapax.set_xlabel("T2 Star value (ms)")
std_mapax.set_ylabel("TR value (ms)")
std_mapax.set_title(str(Period)+" Period error standard deviation map")
#plt.savefig("./SimulationResults/FinalPlots/"+str(Period)+"Period_TR_T2StarErrorSDMap.jpg")
# Out:
# Text(0.5, 1.0, '6 Period error standard deviation map')

# %% [markdown]
# ## T2* Percentag Error Map

# %%
biascb = np.asarray([],dtype = float)
for i in range(0,100):
    biascb = np.append(biascb, 0.05*i)
biasmap, bias_mapax = plt.subplots(figsize = (15,5))

contourImage = bias_mapax.contourf(T2Star_GT*1e3,TR*1e3,np.abs(Biasfigdata)*100,biascb)
c_bar_b = biasmap.colorbar(contourImage, ax=bias_mapax)
c_bar_b.set_label("%")
bias_mapax.set_xlabel("T2 Star value (ms)")
bias_mapax.set_ylabel("TR value (ms)")
bias_mapax.set_title(str(Period)+" Period bias map")
#plt.savefig("./SimulationResults/FinalPlots/"+str(Period)+"Period_TR_T2StarBiasMap.jpg")
# Out:
# Text(0.5, 1.0, '6 Period bias map')

# %% [markdown]
# ## Effective T2* SNR

# %%
figure, ax = plt.subplots(figsize=(10,10))
#estimate effective as Period*TR*500
#SNR = np.asarray([], dtype = float)
for i in range(0,20):
    #if (i == 10):
    SNR = Meanfigdata[i,:]/Errorstdfigdata[i,:]/np.sqrt(Period*TR[i]*500)
    ax.plot(T2Star_GT*1e3,SNR, label = "TR = "+str(TR[i]))
ax.set_xlabel("T2* ms")
ax.set_ylabel("SNR")
ax.legend()
ax.set_title("Period "+str(Period))
# Out:
# Text(0.5, 1.0, 'Period 6')

# %% [markdown]
# ## Visualise the performance difference between different Period

# %% [markdown]
# ## Effective SNR of a select TR for different Periodic ka-SPGR

# %%
figure, ax = plt.subplots(figsize=(10,10))
P = [5,6,7,8,9,10,11,12]
#Load Data
TR_n = 20
T2 = 44e-3
#T2* range 13 ms to 53 ms
T2s_min = 13
T2s_max = 53
T2p = np.asarray([], dtype = float)

for i in range (T2s_min, T2s_max):
    T2p = np.append(T2p, 1/((1000/i)-1/T2))
TR = np.asarray([], dtype = float)
TR_min = 2e-3
TR_max = 10e-3
TR_increment = (TR_max-TR_min)/TR_n
for i in range (0, TR_n):
    TR = np.append(TR, TR_min+TR_increment*i)
    
T2Star_GT = np.asarray([], dtype = float)
for T2_inhom in T2p:
        #Store Ground truth T2*------------------------------------
        T2Star_GT = np.append(T2Star_GT, 1/((1/T2)+(1/T2_inhom)))


for Period in P:        

    Errorstdfigdata = np.load("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/"+str(Period)+"PeriodData_0.05Noise_Errorstd.npy")
    Meanfigdata = np.load("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/"+str(Period)+"PeriodData_0.05Noise_Mean.npy")
    Biasfigdata = np.load("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/"+str(Period)+"PeriodData_0.05Noise_Bias.npy")


    #SNR = np.asarray([], dtype = float)
    for i in range(0,20):
        if (i == 10):
            SNR = Meanfigdata[i,:]/Errorstdfigdata[i,:]/np.sqrt(Period*TR[i]*500)
            print(TR[i])
            ax.plot(T2Star_GT*1e3,SNR, label = "Period = "+str(Period))
            
ax.set_xlabel("T2* ms")
ax.set_ylabel("SNR")
ax.legend()
ax.set_title("TR "+str(TR[10]))
# Out:
# 0.006
# 0.006
# 0.006
# 0.006
# 0.006
# 0.006
# 0.006
# 0.006
# Text(0.5, 1.0, 'TR 0.006')

# %% [markdown]
# # Average Percentage Bias

# %%
P = [5,6,7,8,9,10,11,12]
#P = [5,6,7,8,9,10]
#Load Data
TR_n = 20
T2 = 44e-3
#T2* range 13 ms to 53 ms
T2s_min = 13
T2s_max = 53
T2p = np.asarray([], dtype = float)
fig, ax = plt.subplots(figsize = (15,10))
for Period in P:
    for i in range (T2s_min, T2s_max):
        T2p = np.append(T2p, 1/((1000/i)-1/T2))
    TR = np.asarray([], dtype = float)
    TR_min = 2e-3
    TR_max = 10e-3
    TR_increment = (TR_max-TR_min)/TR_n
    for i in range (0, TR_n):
        TR = np.append(TR, TR_min+TR_increment*i)

    T2Star_GT = np.asarray([], dtype = float)
    for T2_inhom in T2p:
            #Store Ground truth T2*------------------------------------
            T2Star_GT = np.append(T2Star_GT, 1/((1/T2)+(1/T2_inhom)))


    Errorstdfigdata = np.load("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/"+str(Period)+"PeriodData_0.05Noise_Errorstd.npy")
    Meanfigdata = np.load("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/"+str(Period)+"PeriodData_0.05Noise_Mean.npy")
    Biasfigdata = np.load("./SimulationResults/"+str(Period)+"Period_0.05Noise_"+str(TR_n)+"TRs/"+str(Period)+"PeriodData_0.05Noise_Bias.npy")



    #SNR = np.asarray([], dtype = float)
    bias = np.asarray([], dtype = float)
    for i in range(0,20):
        #bias for each TR
        bias_mean = np.mean(Biasfigdata[i,:])
        bias = np.append(bias, bias_mean)

    ax.plot(TR*1e3, bias*100, label = str(Period))
    
legend = ax.legend(title='Periodicity of ka-SPGR', fontsize = 15)
ax.grid(True)
ax.set_xlim(2,9.4)
ax.set_ylim(0,4.5)
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_xlabel("TR (ms)", fontsize = 20)
ax.set_ylabel("Average T2* percentage bias (%)", fontsize = 15)
legend.get_title().set_fontsize('20')
#fig.savefig("figure2.jpg")

# %% [markdown]
# ###
