# %%
import sys
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage import io, transform

from mssfp.phantoms import tissue_map, shepp_logan, generate_block_phantom2d

# %%
print(tissue_map)
# Out:
# {'none': [0, 0], 'water': [4, 2], 'white-matter': [0.6, 0.08], 'gray-matter': [0.9, 0.1], 'muscle': [0.9, 0.05], 'liver': [0.5, 0.04], 'fat': [0.25, 0.07], 'tendon': [0.4, 0.005], 'proteins': [0.25, 0.001]}

# %%
phantom = generate_block_phantom2d()

# %%
plt.imshow(phantom['t1'])

# %%
plt.imshow(phantom['t2'])

# %%
plt.imshow(phantom['fo'])

# %%
phantom = shepp_logan(128)
phantom.shape
plt.imshow(phantom)
plt.show()
